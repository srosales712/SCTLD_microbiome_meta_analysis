# %%
# %cd /space/home/rosales/projects/2020_SCTLD_meta-analysis
# !which qiime
# Out:
# /space/home/rosales/projects/2020_SCTLD_meta-analysis
# /space/home/rosales/anaconda2/envs/qiime2-2020.2/bin/qiime

# %%
# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam145-192 \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam145-192.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam1-48/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam1-48.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam193-240/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam193-240.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam241-288/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam241-288.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam289-336/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam289-336.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam337-387/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam337-387.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam49-96/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam49-96.qza


# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam97-144/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam97-144.qza
# Out:
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam145-192 as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam145-192.qza
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam1-48/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam1-48.qza
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam193-240/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam193-240.qza
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sam241-288/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_sam241-288.qza
# ...

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam145-192.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam145-192.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_145-192.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_145-192
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_145-192.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_145-192.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam1-48.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam1-48.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_1-48.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_1-48
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_1-48.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_1-48.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam193-240.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam193-240.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_193-240.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_193-240
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_193-240.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_193-240.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam241-288.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam241-288.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_241-288.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_241-288
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_241-288.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_241-288.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam289-336.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam289-336.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_289-336.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_289-336
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_289-336.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_289-336.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam337-387.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam337-387.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_337-38.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_337-38
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_337-38.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_337-38.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam49-96.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam49-96.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_49-96.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_49-96
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_49-96.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_49-96.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGmicrobiome2018_sam97-144.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGmicrobiome2018_fastqfiles/sample-metadata-Sam97-144.tsv \
--o-per-sample-sequences demux_Muller_SWGmicro2018_97-144.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGmicro2018_97-144
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGmicro2018_97-144.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGmicro2018_97-144.qza

# %%
# %%bash
#
# for f1 in Folder_SWGmicrobiome2018/demux_Muller_SWGmicro2018_*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime demux summarize \
# --verbose \
# --i-data $f1 \
# --o-visualization Folder_SWGmicrobiome2018/$fn
#
# done

# %%
# %%bash
#
# for f1 in demux_Muller_SWGmicro2018_*.qza
# do
# newfile="$(basename $f1)"
#
# qiime cutadapt trim-paired \
# --i-demultiplexed-sequences $f1 \
# --p-cores 16 \
# --p-front-f GTGCCAGCMGCCGCGGTAA \
# --p-front-r GGACTACVSGGGTATCTAAT \
# --o-trimmed-sequences trim_$newfile \
# --verbose
#
#
# done
# Out:
# This is cutadapt 2.8 with Python 3.6.7
# Command line parameters: --cores 16 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-cdsvlq8r/391.D_7_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-cdsvlq8r/391.D_7_L001_R2_001.fastq.gz --front GTGCCAGCMGCCGCGGTAA -G GGACTACVSGGGTATCTAAT /tmp/qiime2-archive-grt50tfs/d0440f4f-8a92-4332-83aa-b2fca7923724/data/391.D_7_L001_R1_001.fastq.gz /tmp/qiime2-archive-grt50tfs/d0440f4f-8a92-4332-83aa-b2fca7923724/data/391.D_7_L001_R2_001.fastq.gz
# Processing reads on 16 cores in paired-end mode ...
# Finished in 2.64 s (20 us/read; 3.00 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            131,855
#   Read 1 with adapter:                      14 (0.0%)
#   Read 2 with adapter:                   4,562 (3.5%)
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       131,855 (100.0%)
#
# ...

# %%
# %%bash
#
# for f1 in trim_demux_Muller_SWGmicro2018*.qza
# do
# newfile="$(basename $f1)"
# qiime demux summarize  --i-data $f1  --o-visualization $newfile.qzv
#
# done
# Out:
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_145-192.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_1-48.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_193-240.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_241-288.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_289-336.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_337-38.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_49-96.qza.qzv
# Saved Visualization to: trim_demux_Muller_SWGmicro2018_97-144.qza.qzv

# %%
# %%bash
#
# for f1 in Folder_SWGmicrobiome2018/trim_demux_Muller_SWGmicro2018_*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime dada2 denoise-paired --i-demultiplexed-seqs $f1 --p-trunc-len-f 220 --p-trunc-len-r  220 --p-n-threads 10 --o-representative-sequences Folder_SWGmicrobiome2018/rep_$fn.qza --o-table Folder_SWGmicrobiome2018/table_$fn.qza --o-denoising-stats Folder_SWGmicrobiome2018/dada_$fn.qza
#
# done

# %%
# %%bash
#
# for f1 in Folder_SWGmicrobiome2018/trim_demux_Muller_SWGmicro2018_*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime dada2 denoise-single --i-demultiplexed-seqs $f1 --p-max-ee 3 --p-trunc-len 130 --p-n-threads 10 --o-representative-sequences Folder_SWGmicrobiome2018/rep_$fn.qza --o-table Folder_SWGmicrobiome2018/table_$fn.qza --o-denoising-stats Folder_SWGmicrobiome2018/dada_$fn.qza
#
# done
# Out:
# Saved FeatureTable[Frequency] to: Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_145-192.qza
# Saved FeatureData[Sequence] to: Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_145-192.qza
# Saved SampleData[DADA2Stats] to: Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_145-192.qza
# Saved FeatureTable[Frequency] to: Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_1-48.qza
# Saved FeatureData[Sequence] to: Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_1-48.qza
# Saved SampleData[DADA2Stats] to: Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_1-48.qza
# Saved FeatureTable[Frequency] to: Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_193-240.qza
# Saved FeatureData[Sequence] to: Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_193-240.qza
# Saved SampleData[DADA2Stats] to: Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_193-240.qza
# ...

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_97-144.qza \
  --o-visualization Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_97-144.qzv
    
# !qiime feature-table tabulate-seqs \
  --i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_97-144.qza \
 --o-visualization Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_97-144.qzv
# Out:
# Saved Visualization to: Folder_SWGmicrobiome2018/dada_trim_demux_Muller_SWGmicro2018_97-144.qzv
# Saved Visualization to: Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_97-144.qzv

# %%
# !qiime feature-table merge-seqs \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_1-48.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_145-192.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_193-240.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_241-288.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_289-336.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_337-38.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_49-96.qza \
--i-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018_97-144.qza \
--o-merged-data Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018.qza
# Out:
# Saved FeatureData[Sequence] to: Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018.qza

# %%
# !qiime feature-table merge \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_1-48.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_145-192.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_193-240.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_241-288.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_289-336.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_337-38.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_49-96.qza \
 --i-tables Folder_SWGmicrobiome2018/table_trim_demux_Muller_SWGmicro2018_97-144.qza \
 --o-merged-table Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qza \
   --o-visualization Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qzv
# Out:
# Saved Visualization to: Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qzv

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /space/home/rosales/databases/SILVA_DBs/silva-138-99-nb-classifier.qza \
  --i-reads Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018.qza \
  --p-n-jobs -7 \
  --o-classification Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza
# Out:
# Saved FeatureData[Taxonomy] to: Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --o-visualization Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv


# !qiime taxa barplot \
  --i-table  Folder_SWGmicrobiome2018/table-BacArc_Muller_SWGmicrobiome2018.qza \
  --i-taxonomy  Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --m-metadata-file  metadata/metadata_Mulller_SWG.txt \
  --o-visualization  Folder_SWGmicrobiome2018/taxa-bar-Muller_SWGmicrobiome2018.qzv
# Out:
# Saved Visualization to: Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv
# Saved Visualization to: Folder_SWGmicrobiome2018/taxa-bar-Muller_SWGmicrobiome2018.qzv

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --o-visualization Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv
# Out:
# Saved Visualization to: Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv

# %%
# !qiime taxa filter-table \
  --i-table Folder_SWGmicrobiome2018/table_Muller_SWGmicro2018.qza \
  --i-taxonomy  Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --p-exclude mitochondria,chloroplast \
--o-filtered-table Folder_SWGmicrobiome2018/table-BacArc_Muller_SWGmicrobiome2018.qza

# !qiime taxa filter-seqs \
  --i-sequences  Folder_SWGmicrobiome2018/rep_trim_demux_Muller_SWGmicro2018.qza \
  --i-taxonomy   Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --p-exclude mitochondria,chloroplast \
  --o-filtered-sequences Folder_SWGmicrobiome2018/rep_seqs_BacArc_Muller_SWGmicrobiome2018.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_SWGmicrobiome2018/table-BacArc_Muller_SWGmicrobiome2018.qza
# Saved FeatureData[Sequence] to: Folder_SWGmicrobiome2018/rep_seqs_BacArc_Muller_SWGmicrobiome2018.qza

# %%
# !qiime metadata tabulate \
  --m-input-file  Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --o-visualization Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv

# !qiime taxa barplot \
  --i-table Folder_SWGmicrobiome2018/table-BacArc_Muller_SWGmicrobiome2018.qza \
  --i-taxonomy Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qza \
  --m-metadata-file  metadata/metadata_Mulller_SWG.txt \
  --o-visualization Folder_SWGmicrobiome2018/taxa-bar-Muller_SWGmicrobiome.qzv
# Out:
# Saved Visualization to: Folder_SWGmicrobiome2018/taxonomy_Muller_SWGmicrobiome2018.qzv
# Saved Visualization to: Folder_SWGmicrobiome2018/taxa-bar-Muller_SWGmicrobiome.qzv
