# %%
# %env STUDY Apprill_transmissionTissue2019
dir_path='/space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_2019TransmissionExpTissue/'
wdir= "/space/home/rosales/projects/2020_SCTLD_meta-analysis/"
# Out:
# env: STUDY=Apprill_transmissionTissue2019

# %%
# %cd $dir_path
# !ls *.gz > /space/home/rosales/projects/2020_SCTLD_meta-analysis/files_$STUDY.txt
# %cd $wdir
# Out:
# /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_2019TransmissionExpTissue
# /space/home/rosales/projects/2020_SCTLD_meta-analysis

# %%
import pandas as ps
import numpy as np
header_list = ["filepath"]
files_df=ps.read_table('/space/home/rosales/projects/2020_SCTLD_meta-analysis/files_Apprill_transmissionTissue2019.txt',
                                    names=header_list)
files_df[['sample-id', "other"]]= files_df.filepath.str.split("_S",expand=True,)
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'forward-absolute-filepath'] = files_df['filepath'] 
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'reverse-absolute-filepath'] = files_df['filepath']
files_df['forward-absolute-filepath'] = dir_path + files_df['forward-absolute-filepath'].astype(str)
files_df['reverse-absolute-filepath'] = dir_path + files_df['reverse-absolute-filepath'].astype(str)
files_df =files_df[["sample-id","forward-absolute-filepath", "reverse-absolute-filepath"]]
files_df=files_df.drop_duplicates("sample-id")
files_df['reverse-absolute-filepath']=files_df['reverse-absolute-filepath'].str.replace('R1','R2')
files_df.to_csv('/space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv',
index=False, header=True, sep ="\t")

# %%
# !pwd
# Out:
# /space/home/rosales/projects/2020_SCTLD_meta-analysis

# %%
# !mkdir folder_Apprill_transmissionTissue2019
# Out:
# mkdir: cannot create directory ‘folder_Apprill_transmissionTissue2019’: File exists

# %%
# !which qiime
# Out:
# /space/home/rosales/anaconda2/envs/qiime2-2020.2/bin/qiime

# %%
# !grep "sample-id\|LibS*" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibS.csv

# %%
# !grep "sample-id\|LibS" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibS.csv 

# !qiime tools import \
--output-path folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibS.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibS.csv as PairedEndFastqManifestPhred33V2 to folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qza

# %%
# !grep "sample-id\|LibT" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibT.csv 

# !qiime tools import \
--output-path folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibT.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibT.csv as PairedEndFastqManifestPhred33V2 to folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qza

# %%
# !grep "sample-id\|LibU" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibU.csv 

# !qiime tools import \
--output-path folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibU.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibU.csv as PairedEndFastqManifestPhred33V2 to folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qza

# %%
# !grep "sample-id\|LibV" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibV.csv 

# !qiime tools import \
--output-path folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibV.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibV.csv as PairedEndFastqManifestPhred33V2 to folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qza

# %%
# !grep "sample-id\|LibY" /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue.csv \
> /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibY.csv 

# !qiime tools import \
--output-path folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibY.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_2019TransmissionExpTissue_LibY.csv as PairedEndFastqManifestPhred33V2 to folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qza

# %%
# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qza \
--o-visualization folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qza \
--o-visualization folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qza \
--o-visualization folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qza \
--o-visualization folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qza \
--o-visualization folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qzv

# %%
#trim PCR primers
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibS.qza \
--p-cores 2 \
--p-front-f GTGYCAGCMGCCGCGGTAA \
--p-front-r GGACTACNVGGGTWTCTAAT \
--o-trimmed-sequences folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibS.qza \
--verbose


#trim PCR primers
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibT.qza \
--p-cores 2 \
--p-front-f GTGYCAGCMGCCGCGGTAA \
--p-front-r GGACTACNVGGGTWTCTAAT \
--o-trimmed-sequences folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibT.qza \
--verbose


#trim PCR primers
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibU.qza \
--p-cores 2 \
--p-front-f GTGYCAGCMGCCGCGGTAA \
--p-front-r GGACTACNVGGGTWTCTAAT \
--o-trimmed-sequences folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibU.qza \
--verbose


#trim PCR primers
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibV.qza \
--p-cores 2 \
--p-front-f GTGYCAGCMGCCGCGGTAA \
--p-front-r GGACTACNVGGGTWTCTAAT \
--o-trimmed-sequences folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibV.qza \
--verbose


#trim PCR primers
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences folder_Apprill_transmissionTissue2019/Import_Apprill_2019TransmissionExpTissue_LibY.qza \
--p-cores 2 \
--p-front-f GTGYCAGCMGCCGCGGTAA \
--p-front-r GGACTACNVGGGTWTCTAAT \
--o-trimmed-sequences folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibY.qza \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 2 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-r6m4l00v/LibS-1226A-TF-D-MC-T_1_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-r6m4l00v/LibS-1226A-TF-D-MC-T_39_L001_R2_001.fastq.gz --front GTGYCAGCMGCCGCGGTAA -G GGACTACNVGGGTWTCTAAT /tmp/qiime2-archive-3ikussqw/818dbce3-19c0-4faa-b717-0298225b7179/data/LibS-1226A-TF-D-MC-T_1_L001_R1_001.fastq.gz /tmp/qiime2-archive-3ikussqw/818dbce3-19c0-4faa-b717-0298225b7179/data/LibS-1226A-TF-D-MC-T_39_L001_R2_001.fastq.gz
#
# This is cutadapt 2.8 with Python 3.6.7
# ...

# %%
# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibS.qza \
--o-visualization folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibS.

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibT.qza \
--o-visualization folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibT.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibU.qza \
--o-visualization folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibU.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibV.qza \
--o-visualization folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibV.qzv

# !qiime demux summarize \
--verbose \
--i-data folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibY.qza \
--o-visualization folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibY.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibS..qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibT.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibU.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibV.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_LibY.qzv

# %%
# %%bash
#
#
# for f1 in folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_Lib*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime dada2 denoise-single --p-max-ee 3 --i-demultiplexed-seqs $f1 --p-trunc-len 0 --p-n-threads 10 --o-representative-sequences folder_Apprill_transmissionTissue2019/rep_$fn.qza --o-table folder_Apprill_transmissionTissue2019/table_$fn.qza --o-denoising-stats folder_Apprill_transmissionTissue2019/dada_$fn.qza
# #&> DADA2_denoising.log
# done
# Out:
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved SampleData[DADA2Stats] to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved SampleData[DADA2Stats] to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibU.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibU.qza
# ...

# %%
#%%bash

#for f1 in folder_Apprill_transmissionTissue2019/trim_Apprill_2019TransmissionExpTissu_Lib*.qza
#do
#newfile="$(basename $f1)"
#fn=${newfile%.qza};

#qiime dada2 denoise-paired --i-demultiplexed-seqs $f1 --p-trunc-len-f 130 --p-trunc-len-r  130 --p-n-threads 10 --o-representative-sequences folder_Apprill_transmissionTissue2019/rep_$fn.qza --o-table folder_Apprill_transmissionTissue2019/table_$fn.qza --o-denoising-stats folder_Apprill_transmissionTissue2019/dada_$fn.qza 

#done
# Out:
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved SampleData[DADA2Stats] to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibS.qza
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved SampleData[DADA2Stats] to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibT.qza
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibU.qza
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibU.qza
# ...

# %%
# !qiime feature-table merge-seqs \
--i-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibS.qza \
--i-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibT.qza \
--i-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibU.qza \
--i-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibV.qza \
--i-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu_LibY.qza \
--o-merged-data folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qza
# Out:
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qza

# %%
# !qiime metadata tabulate \
--m-input-file folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qza \
--o-visualization folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qzv

# %%
# !qiime feature-table merge \
 --i-tables folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibS.qza \
 --i-tables folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibT.qza \
 --i-tables folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibU.qza \
 --i-tables folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibV.qza \
 --i-tables folder_Apprill_transmissionTissue2019/table_trim_Apprill_2019TransmissionExpTissu_LibY.qza \
 --o-merged-table folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qza
# Out:
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qza

# %%
# !qiime metadata tabulate \
  --m-input-file folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qza \
  --o-visualization folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qzv

# %%
# %%bash
# for f1 in folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_Lib*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime metadata tabulate \
#   --m-input-file $f1 \
#   --o-visualization folder_Apprill_transmissionTissue2019/$fn
#
# done
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibS.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibT.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibU.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibV.qzv
# Saved Visualization to: folder_Apprill_transmissionTissue2019/dada_trim_Apprill_2019TransmissionExpTissu_LibY.qzv

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /space/home/rosales/databases/SILVA_DBs/silva-138-99-nb-classifier.qza \
  --i-reads folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qza \
  --p-n-jobs -7 \
  --o-classification folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza
# Out:
# Saved FeatureData[Taxonomy] to: folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza

# %%
# !qiime taxa filter-seqs \
--i-sequences folder_Apprill_transmissionTissue2019/rep_trim_Apprill_2019TransmissionExpTissu.qza \
--i-taxonomy folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza \
--p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
--o-filtered-sequences folder_Apprill_transmissionTissue2019/rep-BacArc_Apprill_2019TransmissionExpTissu.qza
# Out:
# Saved FeatureData[Sequence] to: folder_Apprill_transmissionTissue2019/rep-BacArc_Apprill_2019TransmissionExpTissu.qza

# %%
# !qiime taxa filter-table \
--i-table folder_Apprill_transmissionTissue2019/table_Apprill_2019TransmissionExpTissu.qza \
--i-taxonomy folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza \
--p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
--o-filtered-table folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qza
# Out:
# Saved FeatureTable[Frequency] to: folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qza

# %%
# !qiime metadata tabulate \
  --m-input-file folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qza \
  --o-visualization folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qzv

# %%
# !qiime metadata tabulate \
  --m-input-file folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza\
  --o-visualization folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qzv

# %%
# !qiime taxa barplot \
  --i-table folder_Apprill_transmissionTissue2019/table-BacArc_Apprill_transmissionTissue2019.qza \
  --i-taxonomy  folder_Apprill_transmissionTissue2019/taxonomy_Apprill_2019TransmissionExpTissu.qza \
  --m-metadata-file  metadata/metadata_Apprill_2019TransmissionExpTissue.txt \
  --o-visualization  folder_Apprill_transmissionTissue2019/taxa-bar-Apprill_2019TransmissionExpTissue.qzv
# Out:
# Saved Visualization to: folder_Apprill_transmissionTissue2019/taxa-bar-Apprill_2019TransmissionExpTissue.qzv
