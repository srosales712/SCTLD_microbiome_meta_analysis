# %%
# %cd /space/home/rosales/projects/2020_SCTLD_meta-analysis
# Out:
# /space/home/rosales/projects/2020_SCTLD_meta-analysis

# %%
# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_139_207_emp-paired-end-sequences/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_Sam_139_207.qza


# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_1_69_emp-paired-end-sequences/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_1_69.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_208_276_emp-paired-end-sequences/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_208_276.qza


# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_277_236_emp-paired-end-sequences/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_277_236.qza

# !qiime tools import \
--type EMPPairedEndSequences \
--input-path /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_70_138_emp-paired-end-sequences/ \
--output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_70_138.qza
# Out:
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_139_207_emp-paired-end-sequences/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGmicrobiome2018_Sam_139_207.qza
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_1_69_emp-paired-end-sequences/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_1_69.qza
# Imported /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/Sam_208_276_emp-paired-end-sequences/ as EMPPairedEndDirFmt to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Import_Muller_SWGtransmissionstudies_Sam_208_276.qza
# ...

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGtransmissionstudies_Sam_139_207.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/sample-metadata-Sam13-207.tsv \
--o-per-sample-sequences demux_Muller_SWGtransmissionstudies_13_207.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGtransmissionstudies_13_207
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGtransmissionstudies_13_207.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGtransmissionstudies_Sam_1_69.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/sample-metadata-Sam1-69.tsv \
--o-per-sample-sequences demux_Muller_SWGtransmissionstudies_1_69.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGtransmissionstudies_1_69
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGtransmissionstudies_1_69.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGtransmissionstudies_Sam_208_276.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/sample-metadata-Sam208-276.tsv \
--o-per-sample-sequences demux_Muller_SWGtransmissionstudies_208-276.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGtransmissionstudies_208-276
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGtransmissionstudies_208-276.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGtransmissionstudies_208-276.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGtransmissionstudies_Sam_277_236.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/sample-metadata-Sam277-326.tsv \
--o-per-sample-sequences demux_Muller_SWGtransmissionstudies_277_236.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGtransmissionstudies_277_236
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGtransmissionstudies_277_236.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGtransmissionstudies_277_236.qza

# %%
# !qiime demux emp-paired \
--i-seqs Import_Muller_SWGtransmissionstudies_Sam_70_138.qza \
--m-barcodes-file /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Muller_SWGtransmissionstudies_fastqfiles/sample-metadata-Sam70-138.tsv\
--o-per-sample-sequences demux_Muller_SWGtransmissionstudies_70_138.qza \
--m-barcodes-column BarcodeSequence \
--p-no-golay-error-correction \
--o-error-correction-details demux_err_Muller_SWGtransmissionstudies_70_138
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: demux_Muller_SWGtransmissionstudies_70_138.qza
# Saved ErrorCorrectionDetails to: demux_err_Muller_SWGtransmissionstudies_70_138.qza

# %%
# %%bash
#
# for f1 in demux_Muller_SWGtransmissionstudies_*.qza
# do
# newfile="$(basename $f1)"
#
# qiime cutadapt trim-paired \
# --i-demultiplexed-sequences $f1 \
# --p-cores 16 \
# --p-front-f GTGCCAGCMGCCGCGGTAA \
# --p-front-r GGACTACVSGGGTATCTAAT \
# --o-trimmed-sequences trim_$newfile \
# --verbose
#
#
# done
# Out:
# This is cutadapt 2.8 with Python 3.6.7
# Command line parameters: --cores 16 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-b3ovgkp9/M.cav.DCA.D1.7.25.19_30_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-b3ovgkp9/M.cav.DCA.D1.7.25.19_30_L001_R2_001.fastq.gz --front GTGCCAGCMGCCGCGGTAA -G GGACTACVSGGGTATCTAAT /tmp/qiime2-archive-959gts87/031527b2-909b-4f13-86e8-bac6d2b8187b/data/M.cav.DCA.D1.7.25.19_30_L001_R1_001.fastq.gz /tmp/qiime2-archive-959gts87/031527b2-909b-4f13-86e8-bac6d2b8187b/data/M.cav.DCA.D1.7.25.19_30_L001_R2_001.fastq.gz
# Processing reads on 16 cores in paired-end mode ...
# Finished in 4.08 s (17 us/read; 3.56 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            241,681
#   Read 1 with adapter:                      78 (0.0%)
#   Read 2 with adapter:                  12,694 (5.3%)
# Pairs that were too short:                   0 (0.0%)
# ...

# %%
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences Folder_Muller_SWGtransmissionstudies/demux_Muller_SWGtransmissionstudies_70_138.qza \
--p-cores 16 \
--p-front-f GTGCCAGCMGCCGCGGTAA \
--p-front-r GGACTACVSGGGTATCTAAT \
--o-trimmed-sequences trim_demux_Muller_SWGtransmissionstudies_70_138.qza \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 16 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-97twbha3/M..cav.Tank.1.E.90percent.6.4.19_5_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-97twbha3/M..cav.Tank.1.E.90percent.6.4.19_5_L001_R2_001.fastq.gz --front GTGCCAGCMGCCGCGGTAA -G GGACTACVSGGGTATCTAAT /tmp/qiime2-archive-2yfvdh80/03c2352d-9227-424f-9397-2bddb7f14f6c/data/M..cav.Tank.1.E.90percent.6.4.19_5_L001_R1_001.fastq.gz /tmp/qiime2-archive-2yfvdh80/03c2352d-9227-424f-9397-2bddb7f14f6c/data/M..cav.Tank.1.E.90percent.6.4.19_5_L001_R2_001.fastq.gz
#
# This is cutadapt 2.8 with Python 3.6.7
# ...

# %%
# %%bash
#
# for f1 in trim_demux_Muller_SWGtransmissionstudies*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime demux summarize  --i-data $f1  --o-visualization $fn.qzv
#
# done
# Out:
# Saved Visualization to: trim_demux_Muller_SWGtransmissionstudies_70_138.qzv

# %%
#%%bash

#for f1 in Folder_Muller_SWGtransmissionstudies/trim_demux_Muller_SWGtransmissionstudies_*.qza
#do
#newfile="$(basename $f1)"
#fn=${newfile%.qza};

#qiime dada2 denoise-paired --i-demultiplexed-seqs $f1 --p-trunc-len-f 220 --p-trunc-len-r  220 --p-n-threads 10 --o-representative-sequences Folder_Muller_SWGtransmissionstudies/rep_$fn.qza --o-table Folder_Muller_SWGtransmissionstudies/table_$fn.qza --o-denoising-stats Folder_Muller_SWGtransmissionstudies/dada_$fn.qza 

#done
# Out:
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved SampleData[DADA2Stats] to: Folder_Muller_SWGtransmissionstudies/dada_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved SampleData[DADA2Stats] to: Folder_Muller_SWGtransmissionstudies/dada_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_208-276.qza
# ...

# %%
# %%bash
#
# for f1 in Folder_Muller_SWGtransmissionstudies/trim_demux_Muller_SWGtransmissionstudies_*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime dada2 denoise-single --i-demultiplexed-seqs $f1 --p-max-ee 3 --p-trunc-len 130 --p-n-threads 10 --o-representative-sequences Folder_Muller_SWGtransmissionstudies/rep_$fn.qza --o-table Folder_Muller_SWGtransmissionstudies/table_$fn.qza --o-denoising-stats Folder_Muller_SWGtransmissionstudies/dada_$fn.qza
#
# done
# Out:
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved SampleData[DADA2Stats] to: Folder_Muller_SWGtransmissionstudies/dada_trim_demux_Muller_SWGtransmissionstudies_13_207.qza
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved SampleData[DADA2Stats] to: Folder_Muller_SWGtransmissionstudies/dada_trim_demux_Muller_SWGtransmissionstudies_1_69.qza
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_208-276.qza
# ...

# %%
# !qiime feature-table merge-seqs \
--i-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_13_207.qza \
--i-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_1_69.qza \
--i-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_208-276.qza \
--i-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_277_236.qza \
--i-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies_70_138.qza \
--o-merged-data Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies.qza
# Out:
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies.qza

# %%
# !qiime feature-table merge \
 --i-tables Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_13_207.qza \
 --i-tables Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_1_69.qza \
 --i-tables Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_208-276.qza \
 --i-tables Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_277_236.qza \
 --i-tables Folder_Muller_SWGtransmissionstudies/table_trim_demux_Muller_SWGtransmissionstudies_70_138.qza \
 --o-merged-table Folder_Muller_SWGtransmissionstudies/table_Muller_SWGtransmissionstudies.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table_Muller_SWGtransmissionstudies.qza

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /space/home/rosales/databases/SILVA_DBs/silva-138-99-nb-classifier.qza \
  --i-reads Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies.qza \
  --p-n-jobs -7 \
  --o-classification Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza
# Out:
# Saved FeatureData[Taxonomy] to: Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza \
  --o-visualization Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qzv


# !qiime taxa barplot \
  --i-table Folder_Muller_SWGtransmissionstudies/table-BacArc_Muller_SWGtransmissionstudies.qza \
  --i-taxonomy Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza \
  --m-metadata-file  metadata/metadata_Muller_SWGTransmission.txt \
  --o-visualization Folder_Muller_SWGtransmissionstudies/taxa-bar-SWGTransmission.qzv
# Out:
# Saved Visualization to: Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qzv
# Saved Visualization to: Folder_Muller_SWGtransmissionstudies/taxa-bar-SWGTransmission.qzv

# %%
# !qiime taxa filter-table \
  --i-table  Folder_Muller_SWGtransmissionstudies/table_Muller_SWGtransmissionstudies.qza \
  --i-taxonomy  Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza \
  --p-exclude mitochondria,chloroplast \
 --p-include d__Bacteria,d__Archaea \
--o-filtered-table Folder_Muller_SWGtransmissionstudies/table-BacArc_Muller_SWGtransmissionstudies.qza

# !qiime taxa filter-seqs \
  --i-sequences  Folder_Muller_SWGtransmissionstudies/rep_trim_demux_Muller_SWGtransmissionstudies.qza \
  --i-taxonomy   Folder_Muller_SWGtransmissionstudies/taxonomy_Muller_SWGtransmissionstudies.qza \
  --p-exclude mitochondria,chloroplast \
 --p-include d__Bacteria,d__Archaea \
  --o-filtered-sequences Folder_Muller_SWGtransmissionstudies/rep_seqs_BacArc_Muller_SWGtransmissionstudies.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_Muller_SWGtransmissionstudies/table-BacArc_Muller_SWGtransmissionstudies.qza
# Saved FeatureData[Sequence] to: Folder_Muller_SWGtransmissionstudies/rep_seqs_BacArc_Muller_SWGtransmissionstudies.qza

# %%
# !qiime vsearch --help
# Out:
# Usage: qiime vsearch [OPTIONS] COMMAND [ARGS]...
#
#   Description: This plugin wraps the vsearch application, and provides
#   methods for clustering and dereplicating features and sequences.
#
#   Plugin website: https://github.com/qiime2/q2-vsearch
#
#   Getting user support: Please post to the QIIME 2 forum for help with this
#   plugin: https://forum.qiime2.org
#
# Options:
#   --version    Show the version and exit.
#   --citations  Show citations and exit.
#   --help       Show this message and exit.
#
# Commands:
#   cluster-features-closed-reference
#                                   Closed-reference clustering of features.
#   cluster-features-de-novo        De novo clustering of features.
#   cluster-features-open-reference
#                                   Open-reference clustering of features.
#   dereplicate-sequences           Dereplicate sequences.
#   fastq-stats                     Fastq stats with vsearch.
# ...
