# %%
# %env STUDY RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017
dir_path='/space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/'
wdir= "/space/home/rosales/projects/2020_SCTLD_meta-analysis/"
# Out:
# env: STUDY=RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017

# %%
# %cd $dir_path
# !ls *.gz > /space/home/rosales/projects/2020_SCTLD_meta-analysis/files_$STUDY.txt
# %cd $wdir
# Out:
# /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017
# /space/home/rosales/projects/2020_SCTLD_meta-analysis

# %%
import pandas as pd
import numpy as np

header_list = ["filepath"]
files_df=pd.read_table('/space/home/rosales/projects/2020_SCTLD_meta-analysis/files_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.txt',
                                    names=header_list)
files_df[['sample-id', "other"]]= files_df.filepath.str.split("_S",expand=True,)
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'forward-absolute-filepath'] = files_df['filepath'] 
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'reverse-absolute-filepath'] = files_df['filepath']
files_df['forward-absolute-filepath'] = dir_path + files_df['forward-absolute-filepath'].astype(str)
files_df['reverse-absolute-filepath'] = dir_path + files_df['reverse-absolute-filepath'].astype(str)
files_df =files_df[["sample-id","forward-absolute-filepath", "reverse-absolute-filepath"]]
files_df=files_df.drop_duplicates("sample-id")
files_df['reverse-absolute-filepath']=files_df['reverse-absolute-filepath'].str.replace('R1','R2')
files_df.to_csv('/space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.csv',
index=False, header=True, sep ="\t")

# %%
# !which qiime
# Out:
# /space/home/rosales/anaconda2/envs/qiime2-2020.2/bin/qiime

# %%
# %cd $wdir
# !mkdir Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017
# Out:
# /space/home/rosales/projects/2020_SCTLD_meta-analysis
# mkdir: cannot create directory ‘Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017’: File exists

# %%
# !qiime tools import \
--output-path Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.csv \
--input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.csv as PairedEndFastqManifestPhred33V2 to Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza

# %%
# !qiime demux summarize \
--verbose \
--i-data Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv
# Out:
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv

# %%
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--p-front-f CCTACGGGNGGCWGCAG\
--p-front-r GACTACHVGGGTATCTAATCC \
--o-trimmed-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-xi9vzulo/SSIDdisease-1_4_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-xi9vzulo/SSIDdisease-1_16_L001_R2_001.fastq.gz --front CCTACGGGNGGCWGCAG -G GACTACHVGGGTATCTAATCC /tmp/qiime2-archive-z632ayn2/d0327f38-131c-4243-9308-70b00d0e2cf0/data/SSIDdisease-1_4_L001_R1_001.fastq.gz /tmp/qiime2-archive-z632ayn2/d0327f38-131c-4243-9308-70b00d0e2cf0/data/SSIDdisease-1_16_L001_R2_001.fastq.gz
#
# This is cutadapt 3.1 with Python 3.6.12
# ...

# %%
# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/Import_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--p-front-f GTGYCAGCMGCCGCGGTAA\
--p-front-r GGACTACNVGGGTWTCTAAT \
--p-error-rate .4 \
--p-discard-untrimmed \
--o-trimmed-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.4 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-dwxk3ahf/SSIDdisease-1_4_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-dwxk3ahf/SSIDdisease-1_16_L001_R2_001.fastq.gz --front GTGYCAGCMGCCGCGGTAA -G GGACTACNVGGGTWTCTAAT --discard-untrimmed /tmp/qiime2-archive-v1px0dk9/d0327f38-131c-4243-9308-70b00d0e2cf0/data/SSIDdisease-1_4_L001_R1_001.fastq.gz /tmp/qiime2-archive-v1px0dk9/d0327f38-131c-4243-9308-70b00d0e2cf0/data/SSIDdisease-1_16_L001_R2_001.fastq.gz
#
# This is cutadapt 3.1 with Python 3.6.12
# ...

# %%
# !qiime demux summarize \
--verbose \
--i-data Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv
# Out:
# /space/home/rosales/miniconda3/envs/qiime2-2020.11/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /space/home/rosales/miniconda3/envs/qiime2-2020.11/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv

# %%
#!qiime dada2 denoise-paired \
#--i-demultiplexed-seqs Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
#--p-trunc-len-f 240 \
#--p-trunc-len-r 181 \
#--p-n-threads 10  \
#--o-representative-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza\
#--o-table Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
#--o-denoising-stats Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017
# Out:
# Usage: qiime dada2 denoise-paired [OPTIONS]
#
#   This method denoises paired-end sequences, dereplicates them, and filters
#   chimeras.
#
# Inputs:
#   --i-demultiplexed-seqs ARTIFACT SampleData[PairedEndSequencesWithQuality]
#                          The paired-end demultiplexed sequences to be
#                          denoised.                                  [required]
# Parameters:
#   --p-trunc-len-f INTEGER
#                          Position at which forward read sequences should be
#                          truncated due to decrease in quality. This truncates
#                          the 3' end of the of the input sequences, which will
#                          be the bases that were sequenced in the last cycles.
#                          Reads that are shorter than this value will be
#                          discarded. After this parameter is applied there must
#                          still be at least a 12 nucleotide overlap between the
# ...

# %%
# !qiime dada2 denoise-single \
--i-demultiplexed-seqs Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/trim_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--p-trunc-len 240 \
--p-n-threads 1  \
--p-max-ee 3 \
--o-representative-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza\
--o-table Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
--o-denoising-stats Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017
# Out:
# Saved FeatureTable[Frequency] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza
# Saved FeatureData[Sequence] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza
# Saved SampleData[DADA2Stats] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv


# !qiime feature-table tabulate-seqs \
  --i-data Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv
# Out:
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/dada_stats_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /space/home/rosales/databases/SILVA_DBs/silva-138-99-nb-classifier.qza \
  --i-reads Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --p-n-jobs -7 \
  --o-classification Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza
# Out:
# Saved FeatureData[Taxonomy] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza

# %%
# !qiime taxa filter-table \
  --i-table Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --i-taxonomy  Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
--o-filtered-table Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table-BacArc_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza

# !qiime taxa filter-seqs \
  --i-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --i-taxonomy  Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
  --o-filtered-sequences Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_BacArc_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table-BacArc_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza
# Saved FeatureData[Sequence] to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/rep_seqs_BacArc_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv


# !qiime taxa barplot \
  --i-table Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/table-BacArc_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --i-taxonomy Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qza \
  --m-metadata-file  metadata/metadata_Rodriguez_SSID_ConchReef.txt \
  --o-visualization Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxa-bar-Rodriguez_SSID_CR.qzv
# Out:
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxonomy_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017.qzv
# Saved Visualization to: Folder_RodriguezLanetty_Bellantuono_SSID_ConchReef_Mar2017/taxa-bar-Rodriguez_SSID_CR.qzv

# %%
# !qiime fragment-insertion sepp --help
# Out:
# Usage: qiime fragment-insertion sepp [OPTIONS]
#
#   Perform fragment insertion of sequences using the SEPP algorithm.
#
# Inputs:
#   --i-representative-sequences ARTIFACT FeatureData[Sequence]
#                        The sequences to insert into the reference tree.
#                                                                     [required]
#   --i-reference-database ARTIFACT SeppReferenceDatabase
#                        The reference database to insert the representative
#                        sequences into.                              [required]
# Parameters:
#   --p-alignment-subset-size INTEGER
#                        Each placement subset is further broken into subsets
#                        of at most these many sequences and a separate HMM is
#                        trained on each subset.                 [default: 1000]
#   --p-placement-subset-size INTEGER
#                        The tree is divided into subsets such that each subset
# ...
