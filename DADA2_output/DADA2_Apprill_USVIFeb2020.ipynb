# %%
# %env STUDY Apprill_USVIFeb2020
# Out:
# env: STUDY=Apprill_USVIFeb2020

# %%
# %%bash
#
# for i in {1..3}
# do
# mkdir "run${i}_folder"
#
# done

# %%
#remove return character from excel file
# !sed -r 's/\r//g' run1April_feb.txt > run1April_febV2.txt
# !sed -r 's/\r//g' run2April_feb.txt > run2April_febV2.txt
# !sed -r 's/\r//g' run3April_feb.txt > run3April_febV2.txt

# %%
# %%bash
# cat run1April_febV2.txt | while read i; do mv $i run1_folder;
# done

# %%
# %%bash
# cat run2April_febV2.txt | while read i; do mv $i run2_folder;
# done

# %%
# %%bash
# cat run3April_febV2.txt | while read i; do mv $i run3_folder;
# done

# %%
# %cd /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run1_folder
# !ls *.gz > /space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run1_$STUDY.txt
# %cd /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run2_folder
# !ls *.gz > /space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run2_$STUDY.txt
# %cd /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run3_folder
# !ls *.gz > /space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run3_$STUDY.txt
# Out:
# /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run2_folder
# /space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run3_folder

# %%
import pandas as ps
import numpy as np


dir_path='/space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run1_folder/'


header_list = ["filepath"]
files_df=ps.read_table('/space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run1_Apprill_USVIFeb2020.txt',
                                    names=header_list)

files_df[['sample-id', "other"]]= files_df.filepath.str.split("_L001",expand=True,)
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'forward-absolute-filepath'] = files_df['filepath'] 
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'reverse-absolute-filepath'] = files_df['filepath']


files_df['forward-absolute-filepath'] = dir_path + files_df['forward-absolute-filepath'].astype(str)
files_df['reverse-absolute-filepath'] = dir_path + files_df['reverse-absolute-filepath'].astype(str)

files_df =files_df[["sample-id","forward-absolute-filepath", "reverse-absolute-filepath"]]

files_df=files_df.drop_duplicates("sample-id")

files_df['reverse-absolute-filepath']=files_df['reverse-absolute-filepath'].str.replace('R1','R2')

files_df.to_csv('/space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run1.csv',
index=False, header=True, sep ="\t")

# %%
dir_path='/space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run2_folder/'


header_list = ["filepath"]
files_df=ps.read_table('/space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run2_Apprill_USVIFeb2020.txt',
                                    names=header_list)

files_df[['sample-id', "other"]]= files_df.filepath.str.split("_L001",expand=True,)
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'forward-absolute-filepath'] = files_df['filepath'] 
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'reverse-absolute-filepath'] = files_df['filepath']


files_df['forward-absolute-filepath'] = dir_path + files_df['forward-absolute-filepath'].astype(str)
files_df['reverse-absolute-filepath'] = dir_path + files_df['reverse-absolute-filepath'].astype(str)

files_df =files_df[["sample-id","forward-absolute-filepath", "reverse-absolute-filepath"]]

files_df=files_df.drop_duplicates("sample-id")

files_df['reverse-absolute-filepath']=files_df['reverse-absolute-filepath'].str.replace('R1','R2')

files_df.to_csv('/space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run2.csv',
index=False, header=True, sep ="\t")

# %%
dir_path='/space/home/rosales/rawdata/2020_SCTLD_16S_meta_analysis/Apprill_USVIFeb2020/run3_folder/'


header_list = ["filepath"]
files_df=ps.read_table('/space/home/rosales/projects/2020_SCTLD_meta-analysis/files_run3_Apprill_USVIFeb2020.txt',
                                    names=header_list)

files_df[['sample-id', "other"]]= files_df.filepath.str.split("_L001",expand=True,)
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'forward-absolute-filepath'] = files_df['filepath'] 
files_df.loc[files_df['filepath'].str.contains('_R1_'), 'reverse-absolute-filepath'] = files_df['filepath']


files_df['forward-absolute-filepath'] = dir_path + files_df['forward-absolute-filepath'].astype(str)
files_df['reverse-absolute-filepath'] = dir_path + files_df['reverse-absolute-filepath'].astype(str)

files_df =files_df[["sample-id","forward-absolute-filepath", "reverse-absolute-filepath"]]

files_df=files_df.drop_duplicates("sample-id")

files_df['reverse-absolute-filepath']=files_df['reverse-absolute-filepath'].str.replace('R1','R2')

files_df.to_csv('/space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run3.csv',
index=False, header=True, sep ="\t")

# %%
# !cd /space/home/rosales/projects/2020_SCTLD_meta-analysis/
# !mkdir Folder_Apprill_USVIFeb2020
# Out:
# mkdir: cannot create directory ‘Folder_Apprill_USVIFeb2020’: File exists

# %%
# %%bash
#
# for f1 in /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run*
# do
# newfile="$(basename $f1)"
# fn=${newfile%.csv};
#
# qiime tools import \
# --output-path /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_$fn \
# --type 'SampleData[PairedEndSequencesWithQuality]' \
# --input-path $f1 \
# --input-format PairedEndFastqManifestPhred33V2
#
# done
# Out:
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run1.csv as PairedEndFastqManifestPhred33V2 to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run1
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run2.csv as PairedEndFastqManifestPhred33V2 to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run2
# Imported /space/home/rosales/projects/2020_SCTLD_meta-analysis/manifest_files/files_Apprill_USVIFeb2020I_run3.csv as PairedEndFastqManifestPhred33V2 to /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run3

# %%
# %%bash
#
# for f1 in /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime demux summarize \
# --verbose \
# --i-data $f1 \
# --o-visualization Folder_Apprill_USVIFeb2020/$fn.qzv
# done
# Out:
# Saved Visualization to: Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run1.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run2.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run3.qzv

# %%
# %%bash
# #trim PCR primers
# for f1 in /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/Import_files_Apprill_USVIFeb2020I_run*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%*.csv};
#
# qiime cutadapt trim-paired \
# --i-demultiplexed-sequences $f1 \
# --p-cores 2 \
# --p-front-f GTGYCAGCMGCCGCGGTAA \
# --p-front-r GGACTACNVGGGTWTCTAAT \
# --o-trimmed-sequences Folder_Apprill_USVIFeb2020/trim_$fn \
# --verbose
#
# done
# Out:
# This is cutadapt 2.8 with Python 3.6.7
# Command line parameters: --cores 2 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-i9_zvo3a/100tiss_S31_0_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-i9_zvo3a/100tiss_S31_41_L001_R2_001.fastq.gz --front GTGYCAGCMGCCGCGGTAA -G GGACTACNVGGGTWTCTAAT /tmp/qiime2-archive-gf2ycjw5/2d4ec927-9a1a-4ec6-baf8-223657f6fd01/data/100tiss_S31_0_L001_R1_001.fastq.gz /tmp/qiime2-archive-gf2ycjw5/2d4ec927-9a1a-4ec6-baf8-223657f6fd01/data/100tiss_S31_41_L001_R2_001.fastq.gz
# Processing reads on 2 cores in paired-end mode ...
# Finished in 2.51 s (23 us/read; 2.60 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            108,860
#   Read 1 with adapter:                 107,151 (98.4%)
#   Read 2 with adapter:                 108,024 (99.2%)
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       108,860 (100.0%)
# ...

# %%
# %%bash
#
# for f1 in /space/home/rosales/projects/2020_SCTLD_meta-analysis/Folder_Apprill_USVIFeb2020/trim*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime demux summarize \
# --verbose \
# --i-data $f1 \
# --o-visualization Folder_Apprill_USVIFeb2020/$fn.qzv
# done
# Out:
# Saved Visualization to: Folder_Apprill_USVIFeb2020/trim_Import_files_Apprill_USVIFeb2020I_run1.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/trim_Import_files_Apprill_USVIFeb2020I_run2.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/trim_Import_files_Apprill_USVIFeb2020I_run3.qzv

# %%
#%%bash

#for f1 in Folder_Apprill_USVIFeb2020/trim_Import_files_Apprill_USVIFeb2020I_run*.qza
#do
#newfile="$(basename $f1)"
#fn=${newfile%.qza};

#qiime dada2 denoise-paired --i-demultiplexed-seqs $f1 --p-trunc-len-f 130 --p-trunc-len-r  130 --p-n-threads 10 --o-representative-sequences Folder_Apprill_USVIFeb2020/rep_$fn.qza --o-table Folder_Apprill_USVIFeb2020/table_$fn.qza --o-denoising-stats Folder_Apprill_USVIFeb2020/dada_$fn.qza 

#done

# %%
# %%bash
#
# for f1 in Folder_Apprill_USVIFeb2020/trim_Import_files_Apprill_USVIFeb2020I_run*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime dada2 denoise-single \
# --i-demultiplexed-seqs $f1 \
# --p-trunc-len 0 \
# --p-n-threads 10 \
# --p-max-ee 3 \
# --o-representative-sequences Folder_Apprill_USVIFeb2020/rep_$fn.qza \
# --o-table Folder_Apprill_USVIFeb2020/table_$fn.qza \
# --o-denoising-stats Folder_Apprill_USVIFeb2020/dada_$fn.qza
#
# done
# Out:
# Saved FeatureTable[Frequency] to: Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run1.qza
# Saved FeatureData[Sequence] to: Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run1.qza
# Saved SampleData[DADA2Stats] to: Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run1.qza
# Saved FeatureTable[Frequency] to: Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run2.qza
# Saved FeatureData[Sequence] to: Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run2.qza
# Saved SampleData[DADA2Stats] to: Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run2.qza
# Saved FeatureTable[Frequency] to: Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run3.qza
# Saved FeatureData[Sequence] to: Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run3.qza
# ...

# %%
# !qiime feature-table merge-seqs \
--i-data Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run1.qza \
--i-data Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run2.qza \
--i-data Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020I_run3.qza \
--o-merged-data Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020.qza
# Out:
# Saved FeatureData[Sequence] to: Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020.qza

# %%
# !qiime feature-table merge \
 --i-tables Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run1.qza \
 --i-tables Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run2.qza \
 --i-tables Folder_Apprill_USVIFeb2020/table_trim_Import_files_Apprill_USVIFeb2020I_run3.qza \
 --o-merged-table Folder_Apprill_USVIFeb2020/table_Apprill_USVIFeb2020I.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_Apprill_USVIFeb2020/table_Apprill_USVIFeb2020I.qza

# %%
# %%bash
# for f1 in Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run*.qza
# do
# newfile="$(basename $f1)"
# fn=${newfile%.qza};
#
# qiime metadata tabulate \
#   --m-input-file $f1 \
#   --o-visualization Folder_Apprill_USVIFeb2020/$fn
#
# done
# Out:
# Saved Visualization to: Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run1.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run2.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/dada_trim_Import_files_Apprill_USVIFeb2020I_run3.qzv

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier /space/home/rosales/databases/SILVA_DBs/silva-138-99-nb-classifier.qza \
  --i-reads Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020.qza \
  --p-n-jobs -7 \
  --o-classification Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza
# Out:
# Saved FeatureData[Taxonomy] to: Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza

# %%
# !qiime taxa filter-seqs \
--i-sequences Folder_Apprill_USVIFeb2020/rep_trim_Import_files_Apprill_USVIFeb2020.qza \
--i-taxonomy Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza \
--p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
--o-filtered-sequences Folder_Apprill_USVIFeb2020/rep-BacArc_Apprill_USVIFeb2020.qza
# Out:
# Saved FeatureData[Sequence] to: Folder_Apprill_USVIFeb2020/rep-BacArc_Apprill_USVIFeb2020.qza

# %%
# !qiime taxa filter-table \
--i-table Folder_Apprill_USVIFeb2020/table_Apprill_USVIFeb2020I.qza \
--i-taxonomy Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza \
--p-exclude mitochondria,chloroplast \
--p-include d__Bacteria,d__Archaea \
--o-filtered-table Folder_Apprill_USVIFeb2020/table-BacArc_Apprill_USVIFeb2020.qza
# Out:
# Saved FeatureTable[Frequency] to: Folder_Apprill_USVIFeb2020/table-BacArc_Apprill_USVIFeb2020.qza

# %%
# !qiime metadata tabulate \
  --m-input-file Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza \
  --o-visualization Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qzv


# !qiime taxa barplot \
  --i-table Folder_Apprill_USVIFeb2020/table-BacArc_Apprill_USVIFeb2020.qza \
  --i-taxonomy Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qza \
  --m-metadata-file  metadata/metadata_Apprill_USVIFeb2020.txt \
  --o-visualization  Folder_Apprill_USVIFeb2020/taxa-bar-Apprill_USVIFeb2020.qzv
# Out:
# Saved Visualization to: Folder_Apprill_USVIFeb2020/taxonomy_Apprill_USVIFeb2020.qzv
# Saved Visualization to: Folder_Apprill_USVIFeb2020/taxa-bar-Apprill_USVIFeb2020.qzv
